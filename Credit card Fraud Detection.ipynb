# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
geniune = df[df.Class==0]
fraud = df[df.Class==1]

# %%
print(geniune.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
geniune.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
geniune_sample = geniune.sample(n=492)

# %%
df_new = pd.concat([geniune_sample, fraud],axis=0)

# %%
df_new.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 175703  122451.0  1.787787 -1.552968 -0.676219 -0.856654 -1.141794 -0.187463
# 180732  124679.0 -0.979180  1.436324  0.357671 -1.005905  0.199195 -0.336103
# 93291    64336.0 -1.259152 -0.487136  2.386151 -0.567041  0.064334  0.660929
# 265338  161843.0  2.120101 -0.671291 -1.065002 -0.555093 -0.852736 -0.919233
# 248484  153961.0 -1.082016  1.338187  0.335817 -0.170646 -0.349929 -0.562060
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 175703 -0.839740  0.014088 -0.159229  ...  0.095171 -0.144723  0.175256
# 180732  0.251427  0.369432  0.817226  ... -0.352973 -0.657544  0.011318
# 93291  -0.876044  0.418149  1.303231  ... -0.029078  0.418090 -0.420255
# 265338 -0.941311 -0.091149  0.060515  ...  0.255638  0.777809  0.186532
# 248484 -0.139190  0.114446  1.275239  ...  0.067807  0.513929  0.215079
#
#              V24       V25       V26       V27       V28  Amount  Class
# 175703 -0.486254 -0.558959 -0.493553 -0.022753 -0.023698  190.00      0
# 180732  0.470953 -0.025517 -0.295287  0.212706 -0.050961    2.99      0
# 93291  -0.344435 -0.374592  0.936623 -0.050626  0.130630   12.67      0
# 265338  1.041073 -0.187810 -0.146077  0.022852 -0.000791   19.95      0
# 248484 -0.115840 -0.938473 -0.553507 -0.347709 -0.033429    1.88      0
#
# [5 rows x 31 columns]

# %%
df_new.shape
# Out:
# (984, 31)

# %%
df_new.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      91416.904472 -0.054414 -0.075013  0.043004  0.137125 -0.037783
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.106902  0.072089  0.000840  0.030149  ...  0.025016 -0.046730
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.000598  0.058863  0.017533 -0.008864  0.004164 -0.005926  0.017491
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      105.882663
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
df_new['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
correlation = df_new.corr()
correlation['Class']
# Out:
# Time     -0.111466
# V1       -0.426480
# V2        0.491117
# V3       -0.568805
# V4        0.694328
# V5       -0.365617
# V6       -0.413423
# V7       -0.476381
# V8        0.058540
# V9       -0.556556
# V10      -0.623502
# V11       0.684638
# V12      -0.679095
# V13      -0.054672
# V14      -0.746076
# V15      -0.035864
# V16      -0.604881
# V17      -0.560646
# V18      -0.453751
# V19       0.274061
# V20       0.145646
# V21       0.136146
# V22       0.005782
# V23      -0.040074
# V24      -0.109086
# V25       0.037517
# V26       0.048428
# V27       0.085116
# V28       0.057920
# Amount    0.028204
# Class     1.000000
# Name: Class, dtype: float64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(correlation, cbar=True, annot=True, fmt='.1f', annot_kws={'size':8})
# Out:
# <AxesSubplot:>

# %%
X = df_new.drop(['Class'], axis=1)
y = df_new['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, random_state=42, test_size=0.1, stratify=y)

# %%
regg = LogisticRegression()

# %%
regg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = regg.predict(x_train)

# %%
score = accuracy_score(pred, y_train)
print(score)
# Out:
# 0.9389830508474576

# %%
pred_test = regg.predict(x_test)

# %%
score_test = accuracy_score(pred_test, y_test)
print(score_test)
# Out:
# 0.9393939393939394
